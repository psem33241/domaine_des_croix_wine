# %% [markdown]
# Félicitations à tous les étudiants qui passent l'examen certifiant de Data Analyst avec la Wild Scode School !
# Vous avez parcouru un chemin remarquable dans votre apprentissage des compétences analytiques et votre maîtrise des techniques de traitement des données.
# Vous serez évalué sur des compétences à travers 4 cas pratiques:
# - SQL, RGPD, Web Scraping et API
# - Pandas
# - Machine Learning
# - Business Case
#
# Vous pouvez effectuer les cas pratiques dans l'ordre que vous souhaitez. Pour vous aider dans votre organisation de travail, vous trouverez une estimation du temps pour chaque partie.
# En ce qui concerne les réponses écrites, pensez à bien soigner les explications, comme si vous répondiez à un client.
#
# ** Votre google collab qui contient toutes vos réponses à l'examen devra être déposé au plus tard (voir mail) dans le dépôt dont le lien vous a été communiqué par mail. **
#
# ---
#
# **Pour le cas pratique "Business Case", votre présentation se décompose sur deux supports:**
# - **Slides de présentations contenant l'introduction (Présentation du contexte et problématique) et la conclusion (recommandations pour le client)**
# - **Dashboard que vous utiliserez pour présenter vos graphiques et tables**
# ---
#
# **Rappel des livrables** :
#
# **BLOC 1,2,3** :
# 1 fichier colab Notebook "Certification Data analyst - Cas Pratiques" avec les résultats attendus et commentés à l’écrit
#
#
# **BLOC 4** :
#
# 1 Fichier Power Bi
#
# 1 Présentation (sous forme .pdf ou .ppt)
#
#
# Veuillez mettre via le lien de dépôt reçu par mail, vos slides sous format .pdf, ainsi que des captures d'écrans de votre tableau de bord à l'intérieur de ce même .pdf. Il est indispensable que tous les éléments pour la présentation soient déposés dans ce dossier, dans le temps imparti.
#
#
# De mercredi à vendredi, auront lieu les oraux pour chaque étudiant.
# Chaque passage à l'oral se déroule de la façon suivante:
#
# 1. Questions du jury à l'étudiant, à partir du google collab qui contient les réponses aux cas pratiques SQL, RGPD, Web Scraping & API, Pandas et Machine Learning. Vous devrez partager votre écran et permettre au formateur de vous poser des questions sur le travail fourni sur votre fichier google collab.
# 2. Présentation du cas pratique "Business Case", d'une durée de 7 minutes, suivi d'une série de questions posées par le formateur.
#
#
# Vous terminerez avec la présentation du cas pratique "Business Case", en répondant au besoin du client comme indiqué dans la partie Cas Pratique.
#
#
#  Bonne chance à tous ! 🎉📊

# %% [markdown]
# ---

# %% [markdown]
# # SQL, RGPD, Web Scraping & API  _(2 heures)_

# %% [markdown]
# ## SQL

# %% [markdown]
# > 1. **Compétence C1.3** Le schéma de la base de données ci-dessous représente plusieurs tables.
# Il existe des relations entre ces tables. **Etablissez les relations entre ses tables, en signifiant à chaque fois quelle est la clé primaire, la clé étrangère.**

# %% [markdown]
# ![Exercice Modélisation.png](data:image/png;base64,...)

# %% [markdown]
# Exemple:
#
# `Table1` --- `Table2`. Clé primaire: `Table2[nom_champ]` Clé étrangère: `Table1[nom_champ]`

# %% [markdown]
# #**Réponse :**
#
# #1) Les clés primaires et étrangères
# Le schéma de base de données ci-dessus présente 6 tables que sont :
#
# **Playlist** ayant pour clé primaire unique **PlaylistId**
#
# **Album** ayant pour clé primaire unique **AlbumId** et clé étrangère unique **ArtistId** qui est obligatoire
#
# **Track** ayant pour clé primaire unique **TrackId** et les clés étrangères **AlbumId**, **MediaTypeId** et **GenreId**. À noter que **GenreId** et **MediaTypeId** semblent être des clés étrangères de tables nommées **Genre** et **MediaType** qui n'apparaissent pas dans le schéma de base données mis à disposition
#
# **InvoiceLine** ayant pour clé primaire unique **InvoiceLineId** et deux clés étrangères : **InvoiceId** qui semble être une clé étrangère appartenant à une table **Invoice** non visible dans le schéma, et **TrackId** appartenant à la table **Track** visible dans le schema mis à disposition
#
# **Artist** ayant pour clé primaire unique **ArtistId**
#
# **PlaylistTrack** ayant pour clé primaire l'association de deux clés étrangères **PlaylistId** et **TrackId** appartenant respectivement aux tables **Playlist** et **Track**
#
# #2) Les associations entre les tables
#
# NB : Les cardinalités minimales ne sont pas clairement définies (d'où les 0/1). De plus en l'état actuel on peut considerer que les clés ne sont pas nullables.
#
# Relation entre **Artist** et **Album** : Relations 0/1 - N (Selon cette base de données, un artiste peut avoir 0, 1 ou plusieurs albums, et un album doit appartenir à exactement un artiste car ArtistId est obligatoire dans Album).
#
# Relation entre **Track** et **Album** : Relations 0/1 - N (Un album peut avoir plusieurs tracks, et un track est associé à au plus un seul album. La cardinalité minimale côté Album n'est pas visible dans le schéma - En réalité un Track pourrait théoriquement exister sans Album, pour que ce soit le cas dans notre bdd il faudrait que AlbumId soit nullable).
#
# Relation entre **Track** et **MediaType** : Relations 1 - N (Un type de média peut être associé à plusieurs tracks, et un track doit avoir exactement un type de média car MediaTypeId est obligatoire. La cardinalité minimale côté MediaType n'est pas visible dans le schéma).
#
# Relation entre **Track** et **Genre** : La table **Genre** n'est pas visible dans le schéma, mais on peut déduire une relation 1 - N (Un genre peut avoir plusieurs tracks, et un track est associé à un seul genre. Les cardinalités minimales ne sont pas déterminables sans plus d'informations).
#
# Relation entre **InvoiceLine** et **Invoice** : La table **Invoice** n'est pas visible mais on peut déduire une relation 1 - N (Une facture peut avoir plusieurs lignes de facture, et une ligne de facture appartient à une seule facture. Les cardinalités minimales ne sont pas déterminables sans plus d'informations).
#
# Relation entre **InvoiceLine** et **Track** : Relations 1 - N (Un track peut apparaître sur 0, 1 ou plusieurs lignes de facture, et une ligne de facture correspond à exactement un track car TrackId est obligatoire).
#
# Relation entre **Playlist** et **Track** : Relation N - N implémentée via la table de jointure **PlaylistTrack** (Une playlist peut contenir plusieurs tracks et un track peut appartenir à plusieurs playlists).

# %% [markdown]
# > 2. **Compétence C1.3** Toujours en se basant sur le schéma de la base de données, existe-t-il une table intermédiaire ? Si oui, quel est le nom de cette table ? Dans quelle situation il est recommandé de créer une table intermédiare pour connecter deux tables ?

# %% [markdown]
# **Réponse:**
#
# Oui il existe une table intermédiaire, il s'agit de **PlaylistTrack**. Cette table fait le lien entre la table **Playlist** et la table **Track**.
#
# Il est recommandé de créer une table intermédiaire dans le cas d'une relation Many to Many (N-N), c'est-à-dire lorsque :
# - Un élément de la première table peut être associé à plusieurs éléments de la deuxième table
# - Un élément de la deuxième table peut être associé à plusieurs éléments de la première table
#
# Dans notre cas :
# - Une playlist peut contenir plusieurs tracks
# - Un track peut appartenir à plusieurs playlists
#
# La table intermédiaire **PlaylistTrack** permet de résoudre cette relation N-N en la décomposant en deux relations 1-N, avec comme clé primaire la combinaison des clés étrangères **PlaylistId** et **TrackId**.

# %% [markdown]
# 3. Requêtes SQL
#
# Exécuter la cellule de code ci-dessous pour se connecter à la base de données.

# %%
import requests
import zipfile
import sqlite3
import pandas as pd

# Here we download the file from GitHub
r = requests.get("https://github.com/WildCodeSchool/wilddata/blob/main/music.zip?raw=true")
open('music.zip', 'wb').write(r.content)

# Then we unzip it
with zipfile.ZipFile("music.zip","r") as zip_ref:
    zip_ref.extractall()

# We connect to the database
conn = sqlite3.connect('music.sqlite')

# %%
# Voici un exemple de requête sql. La requête SQL est entre guillemets pour le premier argument, puis la variable conn en second argument.
pd.read_sql("select * from album", conn)
# Out:
#      AlbumId                                              Title  ArtistId
# 0          1              For Those About To Rock We Salute You         1
# 1          2                                  Balls to the Wall         2
# 2          3                                  Restless and Wild         2
# 3          4                                  Let There Be Rock         1
# 4          5                                           Big Ones         3
# ..       ...                                                ...       ...
# 342      343                             Respighi:Pines of Rome       226
# 343      344  Schubert: The Late String Quartets & String Qu...       272
# 344      345                                Monteverdi: L'Orfeo       273
# 345      346                              Mozart: Chamber Music       274
# 346      347  Koyaanisqatsi (Soundtrack from the Motion Pict...       275
#
# [347 rows x 3 columns]

# %% [markdown]
# Effectuer des requêtes, pour répondre aux questions suivantes.

# %% [markdown]
# > 3.1 **Compétence C1.4** Renvoyer le nom de la playlist qui contient le plus de morceaux, ainsi que le nombre de morceaux pour cette playlist.

# %% [markdown]
# Une réponse rapide consiste en la requete suivante

# %%
pd.read_sql("""
SELECT
    p.PlaylistId,
    p.Name AS nom_playlist,
    COUNT(pt.TrackId) AS nombre_morceaux
FROM
    Playlist p
INNER JOIN PlaylistTrack pt
    ON p.PlaylistId = pt.PlaylistId
GROUP BY
    p.PlaylistId,
    p.Name
ORDER BY
    COUNT(pt.TrackId) DESC
LIMIT 1
""", conn)
# Out:
#    PlaylistId nom_playlist  nombre_morceaux
# 0           1        Music             3290

# %% [markdown]
# La requete ci-après affiche tous les resultats ex-aequo sans utiliser LIMIT c'est à dire sans verification manuelle au prealable (donne directement une information en plus comme quoi la playlist 'Music' apparait 2 fois dans **Playlist** avec deux identifiants différents, pour avoir ce resultat avec la premeire requete il faudrait verifier manuellement au prealable et faire un LIMIT 2 ou 3 en fonction du resultat...)

# %%
pd.read_sql("""
WITH PlaylistCounts AS (
    SELECT
        p.PlaylistId AS playlist_id,
        p.Name AS nom_playlist,
        COUNT(pt.TrackId) AS nombre_morceaux
    FROM
        Playlist p
    INNER JOIN PlaylistTrack pt
        ON p.PlaylistId = pt.PlaylistId
    GROUP BY
        p.PlaylistId,
        p.Name
),
MaxCount AS (
    SELECT MAX(nombre_morceaux) AS max_tracks
    FROM PlaylistCounts
)
SELECT
    pc.playlist_id,
    pc.nom_playlist,
    pc.nombre_morceaux
FROM
    PlaylistCounts pc, MaxCount mc
WHERE
    pc.nombre_morceaux = mc.max_tracks;
""", conn)
# Out:
#    playlist_id nom_playlist  nombre_morceaux
# 0            1        Music             3290
# 1            8        Music             3290

# %% [markdown]
# Résultat attendu:
#
# ![Screenshot 2024-07-11 at 11.17.01.png](data:image/png;base64,...)

# %% [markdown]
# > 3.2 Renvoyer les noms d'artistes, leur nombre de morceaux et leur nombre d'albums par artiste, dans l'ordre décroissant par rapport au nombre de morceaux.

# %%
pd.read_sql("""
SELECT
    a.Name AS Nom_artiste,
    COUNT(DISTINCT t.TrackId) AS Nombre_de_morceaux,
    COUNT(DISTINCT al.AlbumId) AS Nombre_albums
FROM
    Artist a
    INNER JOIN Album al ON a.ArtistId = al.ArtistId
    INNER JOIN Track t ON t.AlbumId = al.AlbumId
GROUP BY
    a.Name, a.ArtistId
ORDER BY
    Nombre_de_morceaux DESC;
""", conn)
# Out:
#                                     Nom_artiste  Nombre_de_morceaux  \
# 0                                   Iron Maiden                 213
# 1                                            U2                 135
# 2                                  Led Zeppelin                 114
# 3                                     Metallica                 112
# 4                                   Deep Purple                  92
# ..                                          ...                 ...
# 199  The 12 Cellists of The Berlin Philharmonic                   1
# 200                                 Ton Koopman                   1
# 201                              Wilhelm Kempff                   1
# 202                              Yehudi Menuhin                   1
# 203                                    Yo-Yo Ma                   1
#
#      Nombre_albums
# 0               21
# 1               10
# 2               14
# 3               10
# 4               11
# ..             ...
# ...

# %% [markdown]
# Résultat attendu:
#
#  ![Solution req 3.png](data:image/png;base64,...)

# %% [markdown]
# > 3.3 **Compétence C1.1** Créer une requête qui renvoie le nombre de morceaux distinct dans la table `Track`. On souhaite renvoyer le nombre de morceaux qui ont des noms différents.

# %%
pd.read_sql("""
SELECT
  COUNT(DISTINCT Name) AS NumberOfUniqueTracks
FROM
  Track;
""", conn)
# Out:
#    NumberOfUniqueTracks
# 0                  3257

# %% [markdown]
# Résultat attendu:
#
# ![Solution req 5.png](data:image/png;base64,...)

# %% [markdown]
# > 3.4. **Compétence C1.2** La maison de disque souhaiterai investir dans les genres qui sont les plus représentés, car ce sont les mieux vendu. Combien de morceaux contient le genre le plus représenté ?

# %% [markdown]
# Résultat attendu :
#
# ![Screenshot 2024-07-11 at 11.25.47.png](data:image/png;base64,...)

# %%
pd.read_sql("""
SELECT
  g.GenreId,
  g.Name,
  COUNT(t.trackId)
FROM
  Track t
INNER JOIN Genre g ON t.GenreId = g.GenreId
GROUP BY
  g.GenreId,
  g.Name
LIMIT 1
;
""", conn)
# Out:
#    GenreId  Name  COUNT(t.trackId)
# 0        1  Rock              1297

# %% [markdown]
# ---

# %% [markdown]
# ## RGPD

# %% [markdown]
# 4: **Compétence C1.7** Que signifie RGPD, et quel est son objectif principal ?

# %% [markdown]
# **Réponse:**
#
# **RGPD** signifie **Règlement Général sur la Protection des Données**. C'est un ensemble de règles que doivent respecter les entreprises situées en Europe ou traitant des données personnelles de citoyens européens. Ces règles visent à encadrer la collecte, le traitement et le partage d'informations à caractère personnel, afin de **protéger** la vie privée des individus et garantir leurs **droits** en matière de données personnelles.
#
# L'objectif principal du RGPD est de donner aux citoyens un **contrôle** accru sur leurs données personnelles tout en unifiant les réglementations de protection des données au sein de l'Union européenne.

# %% [markdown]
# ---

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# 5. **Compétence C1.5** Votre collègue de bureau à qui vous avez partagé le DataFrame `df_all` souhaite récuperer un descriptif de texte pour chaque arrondissement. C'est sa mission, pas la vôtre, donc vous allez vous contenter de répondre à sa question.
# Votre collègue aimerait savoir si sa requête lui a permis d'avoir du contenu en retour.
# Dans un cas, le code `response` lui renvoie "<Response [200]>", et dans l'autre cas, le code `response` lui renvoie "<Response [404]>".
# Il ne comprend pas, et aimerait que vous lui expliquer ce que signifie chacune des deux réponses.
# Soyez le plus clair possible, et écrivez votre réponse comme vous l'auriez expliqué à l'oral.

# %% [markdown]
# **Réponse:**
#
# Lorsque tu envoies une requête pour récupérer des informations, le code `response` te donne un statut qui indique si la requête a réussi ou non.
#
# - Si tu reçois `<Response [200]>`, cela signifie que ta requête a été réussie. C'est un code de statut HTTP qui indique que tout s'est bien passé et que le serveur a renvoyé le contenu que tu cherchais.
#
# - Si tu reçois `<Response [404]>`, cela signifie que ta requête a échoué parce que le serveur n'a pas trouvé ce que tu cherchais. En gros, c'est le code d'erreur "Page non trouvée". Cela peut arriver si l'adresse (ou l'URL) que tu utilises dans ta requête est incorrecte ou si la ressource que tu cherches n'existe pas."
#
# En résumé, retiens tout simplement que `200` c'est bon, et `404` c'est mauvais.

# %% [markdown]
# ---

# %% [markdown]
# ## API

# %% [markdown]
# Voici les données de géolocalisation d'un appartement. L'objectif est de retrouver l'adresse de cet appartement à partir des coordonnées de géolocalisation ("latitude", "longitude"), grâce à une API.

# %%
latitude_appartement = 48.895622
longitude_appartement = 2.337501

# %% [markdown]
# 6. **Compétence C1.6** Utiliser la partie **reverse** de l'API [`https://adresse.data.gouv.fr/api-doc/adresse`](https://adresse.data.gouv.fr/api-doc/adresse) pour récupérer l' adresse de l'appartement, en utilisant les variables "latitude_appartement" et "longitude_appartement".

# %%
import json
import pandas as pd
import requests
link = f"https://api-adresse.data.gouv.fr/reverse/?lon={longitude_appartement}&lat={latitude_appartement}&type=street"
response = requests.get(link)
data = response.json()
data
df = pd.json_normalize(data['features'])
df
# Out:
#       type geometry.type   geometry.coordinates  \
# 0  Feature         Point  [2.337691, 48.895954]
# 1  Feature         Point  [2.337451, 48.896238]
# 2  Feature         Point   [2.33852, 48.895468]
# 3  Feature         Point  [2.338788, 48.895386]
# 4  Feature         Point  [2.338604, 48.894924]
#
#                      properties.label  properties.score properties.id  \
# 0           Rue Joséphine 75018 Paris          0.999999    75118_5021
# 1  Passage du Champ Marie 75018 Paris          0.999998    75118_1728
# 2    Rue Vincent Compoint 75018 Paris          0.999998    75118_9854
# 3      1S4 Impasse Robert 75018 Paris          0.999996  75118_urkhdy
# 4      1S3 Impasse Robert 75018 Paris          0.999995  75118_detgem
#
#           properties.name properties.postcode properties.citycode  \
# 0           Rue Joséphine               75018               75118
# 1  Passage du Champ Marie               75018               75118
# ...

# %%
link = f"https://api-adresse.data.gouv.fr/reverse/?lon={longitude_appartement}&lat={latitude_appartement}&type=street"
response = requests.get(link)
data = response.json()

if response.status_code == 200:
    if 'features' in data and len(data['features']) > 0:
        adresse = data['features'][0]['properties']['label']
        print("Adresse de l'appartement :", adresse)
    else:
        print("Aucune adresse trouvée pour les coordonnées fournies.")
else:
    print(f"Erreur {response.status_code} : {data['message']}")
# Out:
# Adresse de l'appartement : Rue Joséphine 75018 Paris

# %% [markdown]
# ---

# %% [markdown]
# # Pandas _(2 heures)_

# %% [markdown]
# Voici un Dataset `df_transactions` qui regroupe des transactions immobilières de la ville de Paris, entre 2018 et 2019.
# L'objectif de ce cas pratique est de répondre à plusieurs questions.

# %%
import pandas as pd

df_transactions = pd.read_csv("https://raw.githubusercontent.com/WildCodeSchool/wilddata/main/transactions_paris.csv")

df_transactions
# Out:
#       id_mutation  valeur_fonciere  surface_reelle_bati  prix_m2  \
# 0    2019-1064422         156000.0                   19     8210
# 1    2019-1080094         495000.0                   53     9339
# 2    2019-1078635         430000.0                   49     8775
# 3    2019-1069949         216000.0                   30     7200
# 4    2019-1093709         500000.0                   45    11111
# ..            ...              ...                  ...      ...
# 285  2019-1090117         206450.0                   21     9830
# 286  2018-1400990         113000.0                   11    10272
# 287  2018-1391042         315000.0                   30    10500
# 288  2018-1402082         366000.0                   58     6310
# 289  2019-1096647         260000.0                   23    11304
#
#      nombre_pieces_principales   type_local               nom_commune  \
# 0                            1  appartement   Paris 3e Arrondissement
# ...

# %% [markdown]
# > 7. **Compétence C2.6** Supprimer les valeurs aberrantes, qui ont une surface supérieure à 6000 et les insérer dans un DataFrame, nommé `df_outliers`. Renvoyer le nombre de lignes pour ce DataFrame.

# %%
# Filtre des valeurs aberrantes et insertions dans df_outliers
df_outliers = df_transactions[df_transactions['surface_reelle_bati'] > 6000]

# Suppression des valeurs aberrantes du DataFrame original
df_transactions = df_transactions[df_transactions['surface_reelle_bati'] <= 6000]

# Nombre de lignes pour le DataFrame df_outliers
nombre_de_lignes_outliers = df_outliers.shape[0]
print("Nombre de lignes dans df_outliers :", nombre_de_lignes_outliers)
# Out:
# Nombre de lignes dans df_outliers : 4

# %% [markdown]
# > 8. **Compétence C2.6 (deuxième chance)** Vérifier le nombre de valeurs manquantes pour chaque colonne.

# %%
valeurs_manquantes = df_transactions.isnull().sum()
display(valeurs_manquantes)
# Out:
# id_mutation                  0
# valeur_fonciere              0
# surface_reelle_bati          0
# prix_m2                      0
# nombre_pieces_principales    0
# type_local                   0
# nom_commune                  0
# nom_iris                     0
# code_commune                 0
# code_departement             0
# code_iris                    0
# id_parcelles                 0
# longitude                    0
# latitude                     0
# date_mutation                0
# dtype: int64

# %% [markdown]
# > 9. **Compétence C2.5** Observer le nombre de valeurs distinctes pour la colonne "type_local" pour `df_transactions`.

# %%
nombre_valeurs_uniques = df_transactions['type_local'].nunique()
print(f"Nombre de valeurs distinctes pour la colonne 'type_local' :", nombre_valeurs_uniques)
# Out:
# Nombre de valeurs distinctes pour la colonne 'type_local' : 1

# %%
df_transactions['type_local'].value_counts()
# Out:
# type_local
# appartement    286
# Name: count, dtype: int64

# %% [markdown]
# Effectivement il n'a qu'un seul 'type_local' c'est `appartement` (286 en tout, les 290 initiaux moins les 4 valeurs abberrantes retirées)

# %% [markdown]
# > 10. **Compétence C2.5** Quelle est la moyenne de la "surface_reelle_bati" pour chaque valeur de la variable "type_local"?

# %%
print(f"Moyenne surface_reelle_bati = {round(df_transactions['surface_reelle_bati'].mean(),2)} m2")
# Out:
# Moyenne surface_reelle_bati = 47.36 m2

# %% [markdown]
# ---

# %% [markdown]
# ## Regex

# %% [markdown]
# > 11. **Compétence C2.7, Compétence C2.3** Utiliser la librairie `re` (Regular Expression) pour extraire le code postal de l'adresse ci-dessous, à l'aide d'une fonction que vous allez créer:

# %%
adresse = "8 Passage Petit Cerf 75017 Paris"

# %%
import re

def extraire_code_postal(adresse):
    # Expression régulière pour trouver un code postal français (5 chiffres consécutifs)
    pattern = r'\b\d{5}\b' # recherche dans une raw string 5 nombres consecutifs se trouvant à une limite de mots
    match = re.search(pattern, adresse)
    if match:
        return match.group()
    else:
        return None # si pas de resultat, retourne None

# Application
code_postal = extraire_code_postal(adresse)
print("Code postal extrait :", code_postal)
# Out:
# Code postal extrait : 75017

# %% [markdown]
# ## Méthode Agile SCRUM

# %% [markdown]
# > 12. **Compétence C2.2** Dans le cadre de l'utilisation de la méthode agile SCRUM, quelle est la différence entre le scrum master et le product owner ?

# %% [markdown]
# **Réponse :**
#
# Dans la méthode agile SCRUM, le **Scrum Master** facilite les processus et assure l'application des pratiques SCRUM, tandis que le **Product Owner** représente les parties prenantes et gère la définition et la priorisation des fonctionnalités du produit pour maximiser sa valeur. Ils travaillent ensemble pour garantir le bon fonctionnement et la productivité de l'équipe de développement.

# %% [markdown]
# ---

# %% [markdown]
# ## Sélection de données
#
# Voici un nouveau Dataset `df_transactions` qui regroupe des transactions immobilières de la ville de Paris, entre 2018 et 2019.

# %%
import pandas as pd

df_transactions = pd.read_csv("https://raw.githubusercontent.com/WildCodeSchool/wilddata/main/transactions_immobilieres_75.csv")

df_transactions.head(1)
# Out:
#     id_mutation  valeur_fonciere  surface_reelle_bati  prix_m2  \
# 0  2018-1404085         280000.0                   25    11200
#
#    nombre_pieces_principales   type_local               nom_commune  \
# 0                          2  appartement  Paris 20e Arrondissement
#
#        nom_iris  code_commune  code_departement  code_iris    id_parcelles  \
# 0  Belleville 4         75120                75  751207704  75120000AL0064
#
#    longitude  latitude date_mutation
# 0   2.389542   48.8723    2018-01-02

# %% [markdown]
# > 13.**Compétence C2.1** Créer un nouveau DataFrame `df_flats` qui ne regroupe que les appartements. Combien de lignes contient `df_flats` ?

# %%
df_flats = df_transactions[df_transactions['type_local'] == 'appartement'].copy()
print(f"df_flats contient {df_flats.shape[0]} lignes")
# Out:
# df_flats contient 48921 lignes

# %% [markdown]
# # Machine Learning _(4 heures)_

# %% [markdown]
# ## Sélection de données et NLP *(30 minutes)*

# %% [markdown]
# Dans ce cas pratique Machine Learning,  notre objectif sera de créer un algorithme capable de prédire le prix d'appartements, pour la ville de Paris. Vous utiliserez donc le DataFrame `df_flats`.

# %% [markdown]
# > 13. Ne garder que les colonnes [`valeur_fonciere`, `surface_reelle_bati`, `nombre_pieces_principales`, `code_commune`] pour le DataFrame `df_flats`.

# %%
df_flats = df_flats[["valeur_fonciere", "surface_reelle_bati", "nombre_pieces_principales", "code_commune"]]
df_flats
# Out:
#        valeur_fonciere  surface_reelle_bati  nombre_pieces_principales  \
# 0             280000.0                   25                          2
# 1             110000.0                   12                          1
# 2              87950.0                    9                          1
# 3             699000.0                  111                          6
# 4             251000.0                   29                          2
# ...                ...                  ...                        ...
# 53180         215000.0                   18                          1
# 53181         320905.0                   27                          1
# 53182         201000.0                   28                          1
# 53183         283650.0                   28                          1
# 53184         473000.0                   50                          2
#
#        code_commune
# 0             75120
# 1             75114
# 2             75111
# 3             75113
# ...

# %% [markdown]
# > **Compétence C3.5** 14. On aimerait enrichir notre jeu de données avec une variable qui contient du texte pour chaque ligne. Citez un nom de variable explicite, qui permettrait d'enrichir notre jeu de données. En quoi cette variable de texte constituerait une valeur ajoutée pour le jeu de données `df_flats`.  Si vous pourriez créer cette colonne, comment est-ce que vous procéderiez techniquement pour l'exploiter ? Est-ce que cette variable de texte pourrait avoir un impact conséquent sur les performances d'un modèle de prédiction ? Si oui, pourquoi ?

# %% [markdown]
# **Réponse**
#
# Comme nom de variable explicite, on peut envisager une série `description_bien` pour notre dataframe. Ce serait une variable qui contiendrait la description des appartements. En plus des valeurs numériques telles que la surface et la valeur foncière, elle permettrait de répondre directement à plusieurs questions :
#
# - S'agit-il d'un F1, F2, F3, etc. ?
# - Combien de chambres ?
# - Est-ce à l'étage ou en rez-de-chaussée ?
# - Si c'est à l'étage, quel est le numéro de l'étage ? Y a-t-il un ascenseur ?
# - Quel est l'état de l'appartement ?
# - Quels sont les équipements disponibles ?
# - Quel est le type de chauffage ?
# - Etc.
#
# À partir du moment où cette variable textuelle permettrait d'apporter des réponses à ces questions, elle constituerait une valeur ajoutée.
#
# Normalement tout appartement vendu ou à vendre doit avoir une fiche description. Ce sont les informations de cette fiche qui doivent setrouver dans la variable textuelle de notre dataframe. Techniquement, il faudrait appliquer les concepts du NLP (nettoyage, stopwords, lemmatisation, méthode de vectorisation comme TF-IDF) pour transformer les mots en vecteurs, chaque mot de la description pouvant influer sur l'estimation du prix de l'appartement.
#
# En fin de compte, la variable de texte `description_bien` pourrait avoir un impact conséquent sur les performances d'un modèle de prédiction car elle fournit des informations qualitatives détaillées et contextuelles qui enrichissent les données. En utilisant des techniques de traitement du langage naturel (NLP), cette variable peut être transformée en caractéristiques numériques exploitables, ajoutant des nuances et des indices supplémentaires pour améliorer la précision des prédictions. Les descriptions textuelles peuvent révéler des aspects des biens immobiliers non capturés par les variables numériques, comme l'état, les équipements ou la localisation spécifique, offrant ainsi une vue plus complète et précise pour les modèles prédictifs.

# %% [markdown]
# ### Partie Machine Learning - Regression _(1 heure 45 minutes)_
#
# > 14. Créer `X` et `y` en vue d'entraîner un modèle capable de prédire le prix d'appartements.
# `X` est composé des variables `surface_reelle_bati`, `nombre_pieces_principales` et `code_commune`.
# `y` est la variable `valeur_fonciere`.

# %%
X = df_flats[["surface_reelle_bati", "nombre_pieces_principales", "code_commune"]]
y = df_flats[["valeur_fonciere"]]

# %% [markdown]
# > 15. La colonne `code_commune` contient des codes, représentant les arrondissements, ce qui signifie que ce sont des valeurs discrètes. Il est donc nécessaire de créer autant de colonnes qu'il y a de valeurs distinctes pour cette colonne. Aussi, il faudra supprimer la colonne `code_commune` pour ne garder que les colonnes qui ont été générées à partir de cette dernière.

# %%
import pandas as pd

# one-hot pour la colonne 'code_commune'
df_flats_encoded = pd.get_dummies(df_flats, columns=['code_commune'])

# Affichage des premieres lignes du dataframe avec la colonne 'code_commune' encodée
df_flats_encoded.head()
# Out:
#    valeur_fonciere  surface_reelle_bati  nombre_pieces_principales  \
# 0         280000.0                   25                          2
# 1         110000.0                   12                          1
# 2          87950.0                    9                          1
# 3         699000.0                  111                          6
# 4         251000.0                   29                          2
#
#    code_commune_75101  code_commune_75102  code_commune_75103  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    code_commune_75104  code_commune_75105  code_commune_75106  \
# 0               False               False               False
# ...

# %% [markdown]
# > 16. **Compétence C3.2** Séparer les données en jeu d'entraînement et jeu de test, avec `random_state = 0`

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size = 0.15)
print("The length of the initial dataset is :", len(X))
print("The length of the train dataset is   :", len(X_train))
print("The length of the test dataset is    :", len(X_test))
# Out:
# The length of the initial dataset is : 48921
# The length of the train dataset is   : 41582
# The length of the test dataset is    : 7339

# %% [markdown]
# > 17. Importer le modèle `Linear Regression` de la librairie `sklearn`

# %%
from sklearn.linear_model import LinearRegression
# Initialisation du modèle
linear_model = LinearRegression()

# %% [markdown]
# > 18. **Compétence C3.3** Entraîner le modèle sur le jeu d'entraînement, puis évaluer les performances du modèle sur le jeu de test. A l'écrit, interpréter le score obtenu, et donner le nom de la métrique utilisé pour évaluer le score du modèle.

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Évaluation des performances sur le jeu de test
score = linear_model.score(X_test, y_test)

print(f"Le score du modèle sur le jeu de test est : {score}")
# Out:
# Le score du modèle sur le jeu de test est : 0.8412113221928927

# %% [markdown]
# **Interprétation du score**
#
# **La métrique utilisée pour évaluer le score du modèle est le coefficient de détermination (R²). Un score de R² proche de 1 indique que le modèle explique bien la variance des données de test, tandis qu'un score proche de 0 indique qu'il n'explique pas bien la variance.**

# %% [markdown]
# > 19. **Compétence C3.7** Expliquer et vulgariser le fonctionnement interne de l'algorithme, pour qu'il puisse faire ses prédictions.
# Expliquer aussi quelles sont la, ou le(s) variable(s) utilisé par l'algorithme pour faire ses prédictions de prix.

# %% [markdown]
# **Réponse :**

# %% [markdown]
# En régression linéaire, nous sommes dans un cas d'apprentissage supervisé où nous fournissons à l'algorithme des données `X` (caractéristiques) et `y` (valeurs cibles). L'algorithme apprend les relations entre ces données pour pouvoir prédire les prix des appartements lorsqu'on lui présente de nouvelles données. Plus précisément, il essaie de trouver une relation linéaire entre les caractéristiques et les prix, en ajustant les coefficients pour minimiser l'erreur de prédiction. Les variables utilisées par l'algorithme pour faire ses prédictions sont `surface_reelle_bati`, `nombre_pieces_principales`, et les colonnes encodées de `code_commune`.

# %% [markdown]
# > 20. **Compétence C3.1** Afficher la matrice de corrélation pour `df_flats`. Quelles sont les deux variables qui ont la corrélation la plus élevée avec `y`, c'est à dire "valeur foncière" ?

# %% [markdown]
# **Réponse :**

# %%
corr_matrix = df_flats.corr()
corr_matrix
# Out:
#                            valeur_fonciere  surface_reelle_bati  \
# valeur_fonciere                   1.000000             0.908142
# surface_reelle_bati               0.908142             1.000000
# nombre_pieces_principales         0.750153             0.840113
# code_commune                     -0.166078            -0.062434
#
#                            nombre_pieces_principales  code_commune
# valeur_fonciere                             0.750153     -0.166078
# surface_reelle_bati                         0.840113     -0.062434
# nombre_pieces_principales                   1.000000     -0.023447
# code_commune                               -0.023447      1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Afficher la matrice de corrélation
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrice de corrélation pour df_flats')
plt.show()

# %% [markdown]
# Les deux variables ayant la corrélations la plus élevée sont la valeur du bien et sa surface.

# %% [markdown]
# ### Partie Machine Learning - Classification _(1 heure 45 minutes)_

# %%
df_ml_idf = pd.read_csv("https://raw.githubusercontent.com/WildCodeSchool/wilddata/main/transactions_idf_no_paris.csv")
df_ml_idf.head(1)
# Out:
#    valeur_fonciere  surface_reelle_bati  nombre_pieces_principales type_local
# 0         282000.0                  101                          4     maison

# %% [markdown]
# > 21. Créer `X` et `y` en vue d'entraîner un modèle capable de prédire si un logement est une maison ou un appartement.
# `X` est composé des `valeur_fonciere`, `surface_reelle_bati` et`nombre_pieces_principales`.
# `y` est la variable `type_local`.

# %%
X = df_ml_idf[["valeur_fonciere", "surface_reelle_bati", "nombre_pieces_principales"]]
y = df_ml_idf[["type_local"]]

# %% [markdown]
# > 22. Séparer les données en jeu d'entraînement et jeu de test, avec random_state = 0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size = 0.15)
print("The length of the initial dataset is :", len(X))
print("The length of the train dataset is   :", len(X_train))
print("The length of the test dataset is    :", len(X_test))
# Out:
# The length of the initial dataset is : 112583
# The length of the train dataset is   : 95695
# The length of the test dataset is    : 16888

# %% [markdown]
# > 23. Importer le modèle `DecisionTreeClassifier` ou `KNeighborsClassifier` de la librairie sklearn.

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialisation du modèle
decision_tree_model = DecisionTreeClassifier()

# %% [markdown]
# > 24. **Compétence C3.4** Entraîner le modèle sur le jeu d'entraînement, puis évaluer les performances du modèle sur le jeu de test. A l'écrit, interpréter le score obtenu, et donner le nom de la métrique utilisé pour évaluer le score du modèle.

# %%
from sklearn.metrics import accuracy_score

# Entrainement du modèle sur le jeu d'entrainement
decision_tree_model.fit(X_train, y_train)

# Évaluation des performances sur le jeu de test
accuracy = decision_tree_model.score(X_test, y_test)

print(f"Le score de précision du modèle sur le jeu de test est : {accuracy:.2f}")
# Out:
# Le score de précision du modèle sur le jeu de test est : 0.78

# %% [markdown]
# **Réponse :**
#
# Le score obtenu est la **précision** (`accuracy`). La précision mesure la proportion de prédictions correctes par rapport au total des prédictions. Elle est calculée comme le rapport du nombre de prédictions correctes au nombre total de prédictions. Une précision de 1.0 signifie que toutes les prédictions sont correctes, tandis qu'une précision de 0.0 signifie qu'aucune prédiction n'est correcte. Dans notre cas, un e rédiction de 0.78 siggnifie que 78% des prédictes sont correctes. De manière générale, un score de précision élevé indique que le modèle a bien appris à partir des données d'entraînement et qu'il est capable de faire des prédictions précises sur les nouvelles données.

# %% [markdown]
# > 25. **Compétence C3.6** On exploite ici des données pour le jeu d'entraînement, et des données pour le jeu de test. Quelles sont les limites de cette méthode ?

# %% [markdown]
# **Réponse :**
#
# L'utilisation de données séparées pour le jeu d'entraînement et le jeu de test présente des limites, telles que :
#
# - `La sélection de données non représentatives :`
#   Si les données sont sélectionnées de manière non représentative pour le jeu d'entraînement ou le jeu de test, cela peut biaiser les résultats et conduire à des modèles over ou underfitté)
#
# - `la limitation de la taille des échantillons :`
#   Si le jeu de données est petit, la séparation en jeux d'entraînement et de test réduit encore la quantité de données disponibles pour l'entraînement, ce qui peut nuire à la performance du modèle.
#
# - `les difficultés liées à la temporalité des données :`
#   Dans certains cas, les données peuvent avoir une composante temporelle et si la division en jeux d'entraînement et de test ne reflète pas correctement les changements au fil du temps alors cela represente un risque sur la performance du modèle.
#
# Pour pallier ces limites et obtenir une évaluation plus robuste, des méthodes comme la validation croisée peuvent être utilisées, permettant d'exploiter pleinement l'ensemble des données disponibles et d'améliorer la généralisation du modèle.

# %% [markdown]
# > 26. Afficher la matrice de confusion (`confusion matrix`) et la commenter. Expliquer les métriques `precision` et `recall`.

# %% [markdown]
# **Réponse :**

# %%
from sklearn.metrics import confusion_matrix

# Faire des prédictions sur le jeu de test
y_pred = decision_tree_model.predict(X_test)

# Matrice de confusion
conf_matrix = confusion_matrix(y_test, y_pred)

# Affichage de la matrice de confusion avec seaborn
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='coolwarm')
plt.xlabel('Prédictions')
plt.ylabel('Vérités')
plt.title('Matrice de confusion')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Calculer l'exactitude
accuracy = accuracy_score(y_test, y_pred)
print(f"Exactitude : {accuracy:.2f}")

# Calculer la précision
precision = precision_score(y_test, y_pred, average='weighted')
print(f"Précision : {precision:.2f}")

# Calculer le rappel
recall = recall_score(y_test, y_pred, average='weighted')
print(f"Rappel : {recall:.2f}")

# Calculer le F1-score
f1 = f1_score(y_test, y_pred, average='weighted')
print(f"F1-score : {f1:.2f}")
# Out:
# Exactitude : 0.78
# Précision : 0.78
# Rappel : 0.78
# F1-score : 0.78

# %% [markdown]
# La question posée concerne Precision et Recall, nous rajoutons les métriques Exactitude et F1-score afin d'expliciter toutes les métriques d'autant plus qu'il y a souvent très grand econfision entre Accuracy et Precision (de par leur translation).
#
# L'Exactitude (Accuracy) est la proportion de prédictions correctes parmi toutes les prédictions. Sa formule est (TP + TN)/ (TP+TN+FP+FN)
#
# La Précision (Precision) est la proportion de prédictions positives correctes parmi toutes les prédictions positives. (TP)/(TP+FP)
#
# Rappel (Recall) : La proportion de véritables positifs correctement identifiés parmi tous les échantillons réellement positifs. (TP)/(TP+FN)
#
# F1-score : La moyenne harmonique de la précision et du rappel. 2*(Precision*Rappel)/(Precision+Rappel)

# %% [markdown]
# # Étude de marché - Vin _(8 heures)_

# %% [markdown]
# Le client, le Domaine des Croix, cherche à se lancer sur le marché américain . Il souhaite donc **définir le prix** de ses bouteilles de vin **pour être compétitif sur le marché américain**. Il a récupéré un jeu de données de 130k bouteilles de vin, avec les cépages, les pays et région de production, les millésimes (c'est-à-dire les années de production), ainsi que des notes ("points") et descriptifs d'oenologues (les spécialistes du vin), et le prix moyen en dollars de toutes ces bouteilles sur le marché américain.
#
# **L'objectif sera de faire une présentation de l'analyse du marché, et du prix que vous conseillez de fixer pour les vins du client.** Le client n'est pas data analyst, mais souhaiterait comprendre la démarche. Il faudra donc s'attacher à expliquer comment les prix ont été fixés, sans rentrer dans un trop grand niveau technique, autrement dit : vulgariser.
#
#
#
#
# ## Jeux de données
# - Dataset des 130k vins : https://github.com/WildCodeSchool/wilddata/raw/main/wine.zip
# - Dataset de la bouteille de vin que le client aimerait proposer sur le marché américain : https://raw.githubusercontent.com/WildCodeSchool/wilddata/main/domaine_des_croix.csv
#
#
# ## Livrables attendus
# **Compétence C4.6, Compétence C4.1** Le client souhaite une présentation (et non pas du code)
# La présentation contiendra a minima ces éléments :
# - Rappel du contexte et de la problématique
# - Analyse exploratoire des données
# - Méthodologie, outils et langages utilisés  **Compétence C2.2**
# - Présentation de la partie technique et du code créé, si code il y a, pour cette analyse
# - Votre tableau de bord contient des graphiques. **Compétence C4.2**
# - Votre tableau de bord contient au moins une visualisation de données interactive. **Compétence C4.3**
# - Votre tableau de bord contient au moins une carte représentant des informations géographiques. **Compétence C4.4**
# - Votre tableau de bord contient au moins un tableau croisé. **Compétence C4.5**
# - L'ensemble des graphiques et visuels doivent être lisible par tous (prise en compte des personne en situation de handicap visuel). **Compétence C4.7**
# - Réponse à la question métier : proposition de prix ou de fourchette de prix au client pour être correctement positionné face à la concurrence sur le marché américain

# %% [markdown]
# Effectuez tout d'abord la trame ci-dessous. Puis, si vous avez des bonnes idées à proposer au client, elles sont évidemment les bienvenues.

# %% [markdown]
# ## Préparation des données et exploration des données

# %% [markdown]
# ## Analyse du marché
# Le Domaine des Croix souhaiterait une analyse descriptive du marché du vin. Vous allez donc réaliser un ensemble de dataviz, avec l'outil de votre choix (Seaborn, Plotly, Excel, PowerBI, Tableau, etc...). Vous pouvez par exemple intégrer dans votre tableau de bord:
# - la répartition du nombre de vins par pays
# - les pays qui ont les meilleures notes
# - les moyennes de notes par cépage
# - la répartition par décile
# - etc...

# %% [markdown]
# ## Analyse comparative
#
# L'objectif ici sera de comparer chacun des vins du client par rapport à ses concurrents sur le marché. Par exemple, comparer les tarifs pratiqués pour les vins français, puis de plus en plus précisément, les vins de Bourgogne puisque notre client est en Bourgogne, puis les Pinot Noir bourguignons de la même année.
# N'hésitez pas à être original dans la présentation et les dataviz utilisées.
#
# ## Proposition de valeur
#
# Avec le tableau de bord que vous lui avez fourni, le client a une idée précise de ses concurrents. Faites lui une proposition de prix en fonction de sa volonté de positionnement (par exemple : "si vous souhaitez vous positionner sur le haut de gamme, les 25% les plus chers de vos concurrents sont à ce tarif, nous vous conseillons donc de vous aligner sur ce prix").
#
# ## Qualité esthétique du tableau de bord
#
# Essayez de garder un oeil critique et visuel sur votre tableau de bord. La forme compte autant que le fond pour le client qui n'est pas data analyst. Pensez donc à "vendre" votre analyse. Par exemple, avec des couleurs s'inspirant du milieu vinicole, des dataviz originales, etc...

# %% [markdown]
# ## C'est à vous de jouer:

# %%
link = "https://github.com/WildCodeSchool/wilddata/raw/main/wine.zip"
df = pd.read_csv(link)

df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2016, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   20.0              Douro
# 2                                 NaN      87   18.0             Oregon
# 3                Reserve Late Harvest      87   18.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   44.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# Analyse exploratoire rapide

# %% [markdown]
# Top 3 pays representé

# %%
top_countries = df['country'].value_counts().head(5)
print(top_countries)
# Out:
# country
# US          54504
# France      22079
# Italy       19540
# Spain        6645
# Portugal     5691
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=top_countries.values, y=top_countries.index)
plt.title('Top 5 des pays les plus représentés')
plt.xlabel('Nombre de vins')
plt.ylabel('Pays')
plt.show()

# %% [markdown]
# Vins par Pays

# %%
top_5_varieties = df['variety'].value_counts().head(5)
top_5_varieties
# Out:
# variety
# Pinot Noir                  13259
# Chardonnay                  11752
# Cabernet Sauvignon           9472
# Red Blend                    8946
# Bordeaux-style Red Blend     6915
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))
plt.pie(top_5_varieties, labels=top_5_varieties.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 5 des cépages les plus populaires')
plt.show()

# %%
missing_data = df.isnull().sum().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(x=missing_data.values, y=missing_data.index)
plt.title('Répartition des valeurs manquantes')
plt.xlabel('Nombre de valeurs manquantes')
plt.ylabel('Colonnes')
plt.show()

# %%
best_rated_countries = df.groupby('country')['points'].mean().sort_values(ascending=False).head(10)
best_rated_countries
# Out:
# country
# England       91.581081
# India         90.222222
# Austria       90.101345
# Germany       89.851732
# Canada        89.369650
# Hungary       89.191781
# China         89.000000
# France        88.842520
# Luxembourg    88.666667
# Australia     88.580507
# Name: points, dtype: float64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=best_rated_countries.values, y=best_rated_countries.index)
plt.title('Pays avec les meilleures notes moyennes')
plt.xlabel('Note moyenne')
plt.ylabel('Pays')
plt.show()

# %%
df['vintage'] = df['title'].str.extract(r'(\d{4})').astype(float)  # Extraction du millésime des titres

statistics = df.groupby(['variety', 'country', 'vintage']).agg(
    mean_price=('price', 'mean'),
    median_price=('price', 'median'),
    price_range=('price', lambda x: x.max() - x.min())
).reset_index()
statistics
# Out:
#           variety    country  vintage  mean_price  median_price  price_range
# 0        Abouriou     France   2018.0   19.000000          19.0          0.0
# 1        Abouriou     France   2020.0   24.000000          24.0          0.0
# 2        Abouriou         US   2018.0   46.000000          46.0          0.0
# 3     Agiorgitiko     Greece   2009.0   35.000000          35.0         12.0
# 4     Agiorgitiko     Greece   2010.0   43.666667          37.0         32.0
# ...           ...        ...      ...         ...           ...          ...
# 7969     Zweigelt         US   2018.0   29.000000          29.0          0.0
# 7970     Zweigelt         US   2019.0   25.000000          23.0         12.0
# 7971     Zweigelt         US   2021.0   28.000000          28.0          0.0
# 7972    Çalkarası     Turkey   2021.0   17.000000          17.0          2.0
# 7973      Žilavka  Macedonia   2020.0   19.000000          19.0          0.0
#
# [7974 rows x 6 columns]

# %% [markdown]
# Fin analyse exploratoire

# %% [markdown]
# Nettoyage dataframe (uniformisation des données)

# %% [markdown]
# 1) Définition des entêtes de colonnes :
#
# 1. **country** : Le pays d'origine du vin.
# 2. **description** : Une description des arômes, saveurs et caractéristiques du vin.
# 3. **designation** : La désignation spécifique du vin, souvent liée au vignoble ou à une cuvée spéciale.
# 4. **points** : La note attribuée au vin, souvent sur une échelle de 0 à 100.
# 5. **price** : Le prix du vin en dollars.
# 6. **province** : La province ou région principale où le vin est produit.
# 7. **region_1** : Une région plus spécifique à l'intérieur de la province où le vin est produit.
# 8. **region_2** : Une sous-région encore plus spécifique, si applicable.
# 9. **taster_name** : Le nom de l'expert qui a goûté et évalué le vin.
# 10. **taster_twitter_handle** : Le pseudo Twitter de l'expert.
# 11. **title** : Le nom complet du vin, comprenant l'année, le nom du vin et la région.
# 12. **variety** : Le cépage ou l'assemblage de cépages utilisé(s) pour produire le vin.
# 13. **winery** : Le nom du producteur de vin (château ou domaine viticole).

# %% [markdown]
# 2) Nombre exact de lignes dans le dataframe

# %%
print(f"Nombre de lignes : {df.shape[0]}")
# Out:
# Nombre de lignes : 129957

# %% [markdown]
# 3) Verification de la liste des colonnes

# %%
list(df.columns)
# Out:
# ['country',
#  'description',
#  'designation',
#  'points',
#  'price',
#  'province',
#  'region_1',
#  'region_2',
#  'taster_name',
#  'taster_twitter_handle',
#  'title',
#  'variety',
#  'winery',
#  'vintage']

# %% [markdown]
# 4) Y a t'il des vides ou valeurs aberrantes dans la série 'country' ?

# %%
# Lignes où 'country' est nulle, vide, NaN, etc.
null_empty_nan_country = df[df['country'].isna() | df['country'].str.strip().eq('')]

# Affichage des lignes correspondantes
null_empty_nan_country
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# 4243       NaN  Violet-red in color, this semisweet wine has a...
# 9509       NaN  This mouthwatering blend starts with a nose of...
# 9750       NaN  This orange-style wine has a cloudy yellow-gol...
# ...        ...                                                ...
# 124162     NaN  This Swiss red blend is composed of four varie...
# 129393     NaN  Dry spicy aromas of dusty plum and tomato add ...
# 129394     NaN  El Capricho is one of Uruguay's more consisten...
# 129576     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129886     NaN  This wine offers a delightful bouquet of black...
#
#                            designation  points  price province region_1  \
# 913                     Asureti Valley      87   23.0      NaN      NaN
# ...

# %%
null_empty_nan_country['province'].unique()
# Out:
# array([nan], dtype=object)

# %%
null_empty_nan_country['region_1'].unique()
# Out:
# array([nan], dtype=object)

# %%
null_empty_nan_country['region_2'].unique()
# Out:
# array([nan], dtype=object)

# %%
null_empty_nan_country['points'].unique()
# Out:
# array([87, 83, 88, 92, 89, 82, 86, 91, 90, 84, 85])

# %%
null_empty_nan_country['price'].unique()
# Out:
# array([23., nan, 29., 24., 25., 22., 18., 16., 15., 17., 28.,  9., 12.,
#        37., 34., 32., 21., 14., 27., 20., 31., 26., 30., 39., 36.])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(null_empty_nan_country['price'], bins=20, kde=True)
plt.xlabel('Prix')
plt.ylabel('Fréquence')
plt.title('Distribution des prix')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.boxplot(x=null_empty_nan_country['price'])
plt.xlabel('Prix')
plt.title('Boxplot des prix')
plt.show()

# %%
# Calcul des statistiques de base
min_price = null_empty_nan_country['price'].min()
max_price = null_empty_nan_country['price'].max()
avg_price = null_empty_nan_country['price'].mean()
med_price = null_empty_nan_country['price'].median()

# Calcul des quartiles
q1_price = null_empty_nan_country['price'].quantile(0.25)
q3_price = null_empty_nan_country['price'].quantile(0.75)

# Affichage des résultats
print(f"min_price = {min_price}")
print(f"max_price = {max_price}")
print(f"avg_price = {avg_price}")
print(f"med_price = {med_price}")
print(f"q1_price = {q1_price}")
print(f"q3_price = {q3_price}")
# Out:
# min_price = 9.0
# max_price = 39.0
# avg_price = 24.016949152542374
# med_price = 24.0
# q1_price = 21.0
# q3_price = 28.0

# %% [markdown]
# Le dataframe contient 63 lignes dont on ignore les origines (pays, province, region). Certains de ces vins n'ont pas de prix.
#
# Choix : les informations textuelles inconnues seront marqués par 'unknown', les prix manquants par la médiane des prix à peu près confondu avec la moyenne).

# %%
import numpy as np
null_empty_nan_country.loc[:, 'country'] = 'Unknown'
null_empty_nan_country.loc[:, 'province'] = 'Unknown'
null_empty_nan_country.loc[:, 'region_1'] = 'Unknown'
null_empty_nan_country.loc[:, 'region_2'] = 'Unknown'
null_empty_nan_country.loc[:, 'price'] = null_empty_nan_country['price'].fillna(null_empty_nan_country['price'].median())

# %%
# Update de df avec les valeurs modifiées de null_empty_nan_country
df.update(null_empty_nan_country)

# %% [markdown]
# 4) Y a t'il des vides ou valeurs aberrantes dans la série 'description' ?

# %%
# Lignes où 'description' est nulle, vide, NaN, etc.
null_empty_nan_description = df[df['description'].isna() | df['description'].str.strip().eq('')]

# Affichage des lignes correspondantes
null_empty_nan_description
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery, vintage]
# Index: []

# %% [markdown]
# 5) Y a t'il des vides ou valeurs aberrantes dans la série 'designation' ?

# %%
# Lignes où 'designation' est nulle, vide, NaN, etc.
null_empty_nan_designation = df[df['designation'].isna() | df['designation'].str.strip().eq('')]

# Affichage des lignes correspondantes
null_empty_nan_designation
# Out:
#             country                                        description  \
# 2                US  Tart and snappy, the flavors of lime flesh and...
# 7            France  This dry and restrained wine offers spice in p...
# 11           France  This is a dry wine, very spicy, with a tight, ...
# 12               US  Slightly reduced, this wine offers a chalky, t...
# 14               US  Building on 150 years and six generations of w...
# ...             ...                                                ...
# 129938           US  This Zinfandel from the eastern section of Nap...
# 129941  New Zealand  Like Dog Point's 2015 Chardonnay, this wine is...
# 129947        Italy  Intense aromas of wild cherry, baking spice, t...
# 129953           US  Citation is given as much as a decade of bottl...
# 129955       France  A dry style of Pinot Gris, this is crisp with ...
#
#        designation  points  price           province           region_1  \
# ...

# %%
null_empty_nan_designation['designation'].unique()
# Out:
# array([nan], dtype=object)

# %%
null_empty_nan_designation.loc[:, 'designation'] = 'Unknown'

# %%
# Update de df avec les valeurs modifiées de null_empty_nan_designation
df.update(null_empty_nan_designation)

# %%
# Lignes où 'designation' est nulle, vide, NaN, etc.
null_empty_nan_designation = df[df['designation'].isna() | df['designation'].str.strip().eq('')]

# Affichage des lignes correspondantes
null_empty_nan_designation
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery, vintage]
# Index: []

# %% [markdown]
# 6) Y a t'il des vides ou valeurs aberrantes dans la série 'points' ?

# %%
# Lignes où 'points' est nulle, vide, NaN, etc.
null_empty_nan_points = df[df['points'].isna() | df['points'].astype(str).str.strip().eq('')]

# Affichage des lignes correspondantes
null_empty_nan_points
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery, vintage]
# Index: []

# %% [markdown]
# 7) Y a t'il des vides ou valeurs aberrantes dans la série 'price' ?

# %%
# Lignes où 'price' est nulle, vide, NaN, etc.
null_empty_nan_price = df[df['price'].isna() | df['price'].astype(str).str.strip().eq('')]

# Affichage des lignes correspondantes
null_empty_nan_price
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 13         Italy  This is dominated by oak and oak-driven aromas...
# 30        France  Red cherry fruit comes laced with light tannin...
# 31         Italy  Merlot and Nero d'Avola form the base for this...
# 32         Italy  Part of the extended Calanìca series, this Gri...
# ...          ...                                                ...
# 129830     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129846  Portugal  This rich wine has a firm structure as well as...
# 129849  Portugal  This mature wine that has 50% Touriga Nacional...
# 129879     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129950    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
null_empty_nan_price['price'].unique()
# Out:
# array([nan])

# %%
# Calcul des statistiques de base
min_price = df['price'].min()
max_price = df['price'].max()
avg_price = df['price'].mean()
med_price = df['price'].median()

# Calcul des quartiles
q1_price = df['price'].quantile(0.25)
q3_price = df['price'].quantile(0.75)

# Affichage des résultats
print(f"min_price = {min_price}")
print(f"max_price = {max_price}")
print(f"avg_price = {avg_price}")
print(f"med_price = {med_price}")
print(f"q1_price = {q1_price}")
print(f"q3_price = {q3_price}")
# Out:
# min_price = 2.0
# max_price = 1902.0
# avg_price = 36.39041730044309
# med_price = 29.0
# q1_price = 21.0
# q3_price = 42.0

# %%
# Remplacement de 'price' dans 'null_empty_nan_price' par la médiane des prix de 'df'
null_empty_nan_price.loc[:, 'price'] = null_empty_nan_price['price'].fillna(med_price)
# Update de df avec les valeurs modifiées de null_empty_nan_price
df.update(null_empty_nan_price)

# %% [markdown]
# 7) Y a t'il des vides ou valeurs aberrantes dans la série 'province' ?

# %%
# Sélectionner les lignes où 'province' est nulle, vide, NaN, etc.
null_empty_nan_province = df[df['province'].isna() | df['province'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_province
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery, vintage]
# Index: []

# %% [markdown]
# 8) Y a t'il des vides ou valeurs aberrantes dans la série 'region_1' ?

# %%
# Sélectionner les lignes où 'region_1' est nulle, vide, NaN, etc.
null_empty_nan_region_1 = df[df['region_1'].isna() | df['region_1'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_region_1
# Out:
#             country                                        description  \
# 1          Portugal  This is ripe and fruity, a wine that is smooth...
# 8           Germany  Savory dried thyme notes accent sunnier flavor...
# 15          Germany  Zesty orange peels and apple notes abound in t...
# 36            Chile  White flower, lychee and apple aromas carry th...
# 44            Chile  A berry aroma comes with cola and herb notes. ...
# ...             ...                                                ...
# 129942  New Zealand  The blend is 44% Merlot, 33% Cabernet Sauvigno...
# 129944  New Zealand  This blend of Cabernet Sauvignon-Merlot and Ca...
# 129946     Portugal  Fresh and fruity, this is full of red cherry f...
# 129949       Israel  A bouquet of black cherry, tart cranberry and ...
# 129952      Germany  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                               designation  points  price  \
# ...

# %%
null_empty_nan_region_1.loc[:, 'region_1'] = 'Unknown'
# Update de df avec les valeurs modifiées de null_empty_nan_region_1
df.update(null_empty_nan_region_1)

# %% [markdown]
# 9) Y a t'il des vides ou valeurs aberrantes dans la série 'region_2' ?

# %%
# Sélectionner les lignes où 'region_2' est nulle, vide, NaN, etc.
null_empty_nan_region_2 = df[df['region_2'].isna() | df['region_2'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_region_2
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 5          Spain  Blackberry and raspberry aromas show a typical...
# 6          Italy  Here's a bright, informal red that opens with ...
# ...          ...                                                ...
# 129951    France  While it's rich, this beautiful dry wine also ...
# 129952   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129954    France  Well-drained gravel soil gives this wine its c...
# 129955    France  A dry style of Pinot Gris, this is crisp with ...
# 129956    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87   29.0
# ...

# %%
null_empty_nan_region_2.loc[:, 'region_2'] = 'Unknown'
# Update de df avec les valeurs modifiées de null_empty_nan_region_2
df.update(null_empty_nan_region_2)

# %% [markdown]
# 10) Y a t'il des vides ou valeurs aberrantes dans la série 'taster_name' ?

# %%
# Sélectionner les lignes où 'taster_name' est nulle, vide, NaN, etc.
null_empty_nan_taster_name = df[df['taster_name'].isna() | df['taster_name'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_taster_name
# Out:
#        country                                        description  \
# 31       Italy  Merlot and Nero d'Avola form the base for this...
# 32       Italy  Part of the extended Calanìca series, this Gri...
# 33          US  Rustic and dry, this has flavors of berries, c...
# 34          US  This shows a tart, green gooseberry flavor tha...
# 37       Italy  This concentrated Cabernet offers aromas of cu...
# ...        ...                                                ...
# 129838   Italy  Here's an easy blend of Cabernet Sauvignon and...
# 129900      US  Fritz has made tremendous progress with Cab ov...
# 129906      US  Shows the clean, citrus acid juiciness and sil...
# 129915   Italy  This luminous sparkler has a sweet, fruit-forw...
# 129926      US  This is the winery's bells and whistles Chardo...
#
#                          designation  points  price           province  \
# 31      Calanìca Nero d'Avola-Merlot      86   29.0  Sicily & Sardinia
# ...

# %%
null_empty_nan_taster_name.loc[:, 'taster_name'] = 'Unknown'
null_empty_nan_taster_name.loc[:, 'taster_twitter_handle'] = 'Unknown'
# Update de df avec les valeurs modifiées de null_empty_nan_taster_name
df.update(null_empty_nan_taster_name)

# %% [markdown]
# 11) Y a t'il des vides ou valeurs aberrantes dans la série 'taster_twitter_handle' ?

# %%
# Sélectionner les lignes où 'taster_name' est nulle, vide, NaN, etc.
null_empty_nan_taster_twitter_handle = df[df['taster_twitter_handle'].isna() | df['taster_twitter_handle'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_taster_twitter_handle
# Out:
#         country                                        description  \
# 3            US  Pineapple rind, lemon pith and orange blossom ...
# 8       Germany  Savory dried thyme notes accent sunnier flavor...
# 15      Germany  Zesty orange peels and apple notes abound in t...
# 19           US  Red fruit aromas pervade on the nose, with cig...
# 20           US  Ripe aromas of dark berries mingle with ample ...
# ...         ...                                                ...
# 129860       US  While blossom and melon aromas on this Gewürzt...
# 129896  Germany  Sun-kissed nectarine, tangerine and grapefruit...
# 129897  Germany  Dusty pollen and mineral notes lend spicy, sav...
# 129932  Germany  Plump, clingy peach and honey notes are cut wi...
# 129952  Germany  Notes of honeysuckle and cantaloupe sweeten th...
#
#                                    designation  points  price     province  \
# 3                         Reserve Late Harvest      87   18.0     Michigan
# ...

# %%
null_empty_nan_taster_twitter_handle.loc[:, 'taster_twitter_handle'] = 'Unknown'
# Update de df avec les valeurs modifiées de null_empty_nan_taster_twitter_handle
df.update(null_empty_nan_taster_twitter_handle)

# %% [markdown]
# 12) Y a t'il des vides ou valeurs aberrantes dans la série 'title' ?

# %%
# Sélectionner les lignes où 'title' est nulle, vide, NaN, etc.
null_empty_nan_title = df[df['title'].isna() | df['title'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_title
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery, vintage]
# Index: []

# %% [markdown]
# 13) Y a t'il des vides ou valeurs aberrantes dans la série 'variety' ?

# %%
# Sélectionner les lignes où 'variety' est nulle, vide, NaN, etc.
null_empty_nan_variety = df[df['variety'].isna() | df['variety'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_variety
# Out:
#       country                                        description designation  \
# 86900   Chile  A chalky, dusty mouthfeel nicely balances this...     Unknown
#
#        points  price      province region_1 region_2 taster_name  \
# 86900      88   36.0  Maipo Valley  Unknown  Unknown     Unknown
#
#       taster_twitter_handle                        title variety  winery  \
# 86900               Unknown  Carmen 2005  (Maipo Valley)     NaN  Carmen
#
#        vintage
# 86900   2005.0

# %%
null_empty_nan_variety.loc[:, 'taster_name'] = 'Cabernet Sauvignon'

# %%
# Update de df avec les valeurs modifiées de null_empty_nan_variety
df.update(null_empty_nan_variety)

# %% [markdown]
# 14) Y a t'il des vides ou valeurs aberrantes dans la série 'winery' ?

# %%
# Sélectionner les lignes où 'winery' est nulle, vide, NaN, etc.
null_empty_nan_winery = df[df['winery'].isna() | df['winery'].str.strip().eq('')]

# Afficher les lignes correspondantes
null_empty_nan_winery
# Out:
# Empty DataFrame
# Columns: [country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery, vintage]
# Index: []

# %% [markdown]
# 15) Vérification du type des colonnes

# %%
df.dtypes
# Out:
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# vintage                  float64
# dtype: object

# %%
# Identifier les colonnes catégorielles (de type object)
categorical_columns = df.select_dtypes(include=['object']).columns

# Vérifier et enlever les espaces en trop dans les colonnes catégorielles
for col in categorical_columns:
    df[col] = df[col].str.strip()

# Afficher le DataFrame nettoyé
df
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2016, this...
# ...          ...                                                ...
# 129952   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129953        US  Citation is given as much as a decade of bottl...
# 129954    France  Well-drained gravel soil gives this wine its c...
# 129955    France  A dry style of Pinot Gris, this is crisp with ...
# 129956    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87   29.0
# ...

# %% [markdown]
# Création d'une colonne catégorielle basée sur le prix

# %%
# Analysons la distribution des prix pour déterminer les catégories
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=50)
plt.title('Distribution des prix')
plt.xlabel('Prix')
plt.ylabel('Fréquence')
plt.xscale('log')  # Échelle logarithmique pour mieux visualiser

# %%
# Définition des seuils pour les catégories de prix
# Après analyse de la distribution, on peut définir des catégories pertinentes
def categorize_price(price):
    if price < 10:
        return 'Très bas'
    elif price < 50:
        return 'Bas'
    elif price < 100:
        return 'Moyen'
    elif price < 200:
        return 'Élevé'
    elif price < 500:
        return 'Très élevé'
    else:
        return 'Premium'

# Ajout de la nouvelle fonctionnalité
df['price_category'] = df['price'].apply(categorize_price)

# Ajout d'une fonctionnalité numérique pour les modèles
df['price_category_code'] = df['price_category'].map({
    'Très bas': 0,
    'Bas': 1,
    'Moyen': 2,
    'Élevé': 3,
    'Très élevé': 4,
    'Premium': 5
})

# %%
# Analyse des statistiques par catégorie
category_stats = df.groupby('price_category')['price'].agg(['count', 'min', 'max', 'mean', 'median']).reset_index()
print("Statistiques par catégorie de prix:")
category_stats
# Out:
# Statistiques par catégorie de prix:
#   price_category   count    min     max        mean  median
# 0            Bas  107874   10.0    49.0   27.621197    28.0
# 1          Moyen   17825   50.0    99.0   64.953100    61.0
# 2        Premium      63  502.0  1902.0  775.063492   674.0
# 3       Très bas    1096    2.0     9.0    7.723540     8.0
# 4     Très élevé     462  200.0   497.0  283.010823   254.5
# 5          Élevé    2637  100.0   199.0  127.915813   120.0

# %%
# Visualisation de la répartition des catégories de prix
plt.figure(figsize=(10, 6))
plt.bar(df['price_category'].value_counts().index, df['price_category'].value_counts().values)
plt.title('Répartition des catégories de prix')
plt.xlabel('Catégorie')
plt.ylabel('Nombre d\'observations')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Bas'),
#   Text(1, 0, 'Moyen'),
#   Text(2, 0, 'Élevé'),
#   Text(3, 0, 'Très bas'),
#   Text(4, 0, 'Très élevé'),
#   Text(5, 0, 'Premium')])

# %%
# Conversion de la colonne 'price_category_code' en type objet
df['price_category_code'] = df['price_category_code'].astype(object)

# %%
# enregistrement du dataframe nettoyé dans un fichier CSV
df.to_csv('wine_dataset.csv', index=False, encoding='utf-8')

# %% [markdown]
# Dataset du client

# %%
link = "https://raw.githubusercontent.com/WildCodeSchool/wilddata/main/domaine_des_croix.csv"
df_client = pd.read_csv(link)

df_client.head()
# Out:
#   country                                        description  designation  \
# 0  France  Firm and solid with great swathes of black fru...          NaN
#
#    points  price  province       region_1  region_2 taster_name  \
# 0      94    NaN  Burgundy  Corton Grèves       NaN  Roger Voss
#
#   taster_twitter_handle                                  title     variety  \
# 0            @vossroger  Domaine des Croix 2016  Corton Grèves  Pinot Noir
#
#               winery
# 0  Domaine des Croix

# %%
# on a qu'une ligne dans df_client
df_client.loc[:, 'designation'] = 'Corton Grèves'
# Out:
# <ipython-input-406-b5c690437558>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Corton Grèves' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_client.loc[:, 'designation'] = 'Corton Grèves'

# %%
df_client
# Out:
#   country                                        description    designation  \
# 0  France  Firm and solid with great swathes of black fru...  Corton Grèves
#
#    points  price  province       region_1  region_2 taster_name  \
# 0      94    NaN  Burgundy  Corton Grèves       NaN  Roger Voss
#
#   taster_twitter_handle                                  title     variety  \
# 0            @vossroger  Domaine des Croix 2016  Corton Grèves  Pinot Noir
#
#               winery
# 0  Domaine des Croix

# %%
# enregistrement de df_client
df_client.to_csv('client_wine.csv', index=False, encoding='utf-8')

# %% [markdown]
# export en parquets

# %%
df.to_parquet('wine_dataset.parquet', index=False)
df_client.to_parquet('client_wine.parquet', index=False)
